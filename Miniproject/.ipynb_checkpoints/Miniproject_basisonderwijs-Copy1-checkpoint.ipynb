# %% [markdown]
# # Cito Toets
#
# #### Stap 1 Data verzamelen
# * We halen de webpagina op waar eea in wordt uitgelegd, en het excel bestand met alle gegevens.
#     * <http://www.rtlnieuws.nl/nieuws/binnenland/hoe-vergelijkt-rtl-nieuws-de-cito-scores-van-2014>
#     * <http://www.rtlnieuws.nl/sites/default/files/content/documents/2014/07/07/scholenoverzicht_0.xls>
#
# #### Stap 2 Inlezen in pandas, en wat eerste exploratie
# * Hier wordt het prima uitgelegd:
#     * <http://pbpython.com/pandas-pivot-table-explained.html>
#
# #### Stap 3 Analyse

# %% [markdown]
# # Data verzamelen

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
# Out:
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
scholenoverzicht = pd.read_excel("http://maartenmarx.nl/teaching/ISatWork/Data/CitoToets/scholenoverzicht_0.xls")
scholenoverzicht.head()
# Out:
#    BRIN  Vestiging      id                naam                 adres postcode  \
# 0  23EK          0  23EK00          De Phoenix            Zalmkolk 2  8017 PA
# 1  09CA          0  09CA00         Jan Jaspers         de Meenthe 28  8051 KV
# 2  30RP          0  30RP00       De Verbinding  Jan Greshoffstraat 5  3069 WG
# 3  30PN          0  30PN00         EBS Tabitha     Jachthoornlaan 15  7312 CD
# 4  15UF          0  15UF00  obs De Springplank       Beukenstraat 83  8021 XA
#
#       plaats   gemeente     provincie              denominatie   ...     \
# 0     Zwolle     Zwolle    Overijssel          Rooms-Katholiek   ...
# 1     Hattem     Hattem    Gelderland  Protestants-Christelijk   ...
# 2  Rotterdam  Rotterdam  Zuid-Holland       Algemeen Bijzonder   ...
# 3  Apeldoorn  Apeldoorn    Gelderland              Evangelisch   ...
# 4     Zwolle     Zwolle    Overijssel                 Openbaar   ...
#
#   tellerdeelname noemerdeelname deelnaamper meantoets  waretoets      RES1  \
# 0
# 1             29             29         100  -0.46357   -0.46357  -1.01519
# 2
# 3
# 4           20.5           23.5      87.234  0.222755 -0.0580963  0.763355
#
#       PRED1   quasicito    verwacht   cijfer
# 0  0.910815         NaN  537.351861        -
# 1  0.551622  531.447503  535.808769        -
# 2  0.178813         NaN  534.207181        -
# 3  0.415624         NaN  535.224522        -
# 4 -0.821451  533.189418  529.910046  7.76335
#
# [5 rows x 57 columns]

# %%
scholenoverzicht_toetsen = scholenoverzicht[['BRIN', 'naam', 'adres', 'postcode', 'plaats', 'gemeente', 'provincie',\
                                     'denominatie', 'visie', 'TOETS_2012', 'SCORE_2012', 'TOETS_2013', 'SCORE_2013', 'TOETS_2014', 'SCORE_2014']]
scholenoverzicht_toetsen.head()
# Out:
#    BRIN                naam                 adres postcode     plaats  \
# 0  23EK          De Phoenix            Zalmkolk 2  8017 PA     Zwolle
# 1  09CA         Jan Jaspers         de Meenthe 28  8051 KV     Hattem
# 2  30RP       De Verbinding  Jan Greshoffstraat 5  3069 WG  Rotterdam
# 3  30PN         EBS Tabitha     Jachthoornlaan 15  7312 CD  Apeldoorn
# 4  15UF  obs De Springplank       Beukenstraat 83  8021 XA     Zwolle
#
#     gemeente     provincie              denominatie     visie TOETS_2012  \
# 0     Zwolle    Overijssel          Rooms-Katholiek  Regulier        NaN
# 1     Hattem    Gelderland  Protestants-Christelijk  Regulier        NaN
# 2  Rotterdam  Zuid-Holland       Algemeen Bijzonder  Regulier        NaN
# 3  Apeldoorn    Gelderland              Evangelisch  Regulier        NaN
# 4     Zwolle    Overijssel                 Openbaar  Regulier        NaN
#
#   SCORE_2012 TOETS_2013 SCORE_2013 TOETS_2014 SCORE_2014
# 0                   NaN                andere
# 1                   NaN                   seo      -0.57
# 2                   NaN                   NaN
# 3                   NaN                andere
# 4                   SEO      -0.43        seo       0.81

# %%
scholenoverzicht_cito = scholenoverzicht_toetsen[(scholenoverzicht_toetsen.TOETS_2012 =='cito') & \
                                                    (scholenoverzicht_toetsen.TOETS_2013 =='cito') & \
                                                    (scholenoverzicht_toetsen.TOETS_2014 =='cito')]

scholenoverzicht_cito.head()
# Out:
#      BRIN                                naam                 adres postcode  \
# 207  07OL     Rotterdamse Schoolvereniging II     Stuart Millpad 84  3076 RK
# 208  08XI  Rotterdamse Schoolvereniging Noord  Schiedamsesingel 155  3012 BB
# 209  16KZ         Professor Wassenberghschool         Ieborchpaed 6  9081 AR
# 210  03HI      de Gereformeerde b.s. Rehoboth   Pompenburgsingel 30  3135 PS
# 211  03BA    Basisschool Jan van Rijckenborgh  's-Gravesandelaan 15  1222 SX
#
#           plaats     gemeente      provincie               denominatie  \
# 207    Rotterdam    Rotterdam   Zuid-Holland        Algemeen Bijzonder
# 208    Rotterdam    Rotterdam   Zuid-Holland        Algemeen Bijzonder
# 209       Lekkum   Leeuwarden      Friesland                  Openbaar
# 210  Vlaardingen  Vlaardingen   Zuid-Holland  Gereformeerd Vrijgemaakt
# 211    Hilversum    Hilversum  Noord-Holland        Algemeen Bijzonder
#
#         visie TOETS_2012 SCORE_2012 TOETS_2013 SCORE_2013 TOETS_2014  \
# 207  Regulier       cito      546.4       cito      543.5       cito
# 208  Regulier       cito      540.5       cito      543.2       cito
# 209  Regulier       cito        535       cito      532.8       cito
# 210  Regulier       cito      535.7       cito      537.2       cito
# 211  Regulier       cito      540.2       cito      545.8       cito
#
#     SCORE_2014
# 207      545.2
# 208      541.2
# 209      521.5
# 210      535.1
# 211      531.8

# %%
scholenoverzicht_citoscores = scholenoverzicht_cito.drop(['TOETS_2012', 'TOETS_2013', 'TOETS_2014'], axis=1).rename(columns = {'BRIN':'BRIN NUMMER'})
scholenoverzicht_citoscores.head()
# Out:
#     BRIN NUMMER                                naam                 adres  \
# 207        07OL     Rotterdamse Schoolvereniging II     Stuart Millpad 84
# 208        08XI  Rotterdamse Schoolvereniging Noord  Schiedamsesingel 155
# 209        16KZ         Professor Wassenberghschool         Ieborchpaed 6
# 210        03HI      de Gereformeerde b.s. Rehoboth   Pompenburgsingel 30
# 211        03BA    Basisschool Jan van Rijckenborgh  's-Gravesandelaan 15
#
#     postcode       plaats     gemeente      provincie  \
# 207  3076 RK    Rotterdam    Rotterdam   Zuid-Holland
# 208  3012 BB    Rotterdam    Rotterdam   Zuid-Holland
# 209  9081 AR       Lekkum   Leeuwarden      Friesland
# 210  3135 PS  Vlaardingen  Vlaardingen   Zuid-Holland
# 211  1222 SX    Hilversum    Hilversum  Noord-Holland
#
#                   denominatie     visie SCORE_2012 SCORE_2013 SCORE_2014
# 207        Algemeen Bijzonder  Regulier      546.4      543.5      545.2
# 208        Algemeen Bijzonder  Regulier      540.5      543.2      541.2
# 209                  Openbaar  Regulier        535      532.8      521.5
# 210  Gereformeerd Vrijgemaakt  Regulier      535.7      537.2      535.1
# 211        Algemeen Bijzonder  Regulier      540.2      545.8      531.8

# %%
xl_file = pd.ExcelFile('02.Onderwijspersoneel_po_in_fte-2010-2014_.xls', axis=0)

dfs = {sheet_name: xl_file.parse(sheet_name)
       for sheet_name in xl_file.sheet_names}


pers_fte = dfs['per owtype-bestuur-brin-functie'][["BRIN NUMMER", "FUNCTIEGROEP", "FTE'S 2012", "FTE'S 2013", "FTE'S 2014"]]
pers_fte_onderwijsgevend = pers_fte[pers_fte.FUNCTIEGROEP == 'Onderwijsgevend personeel']
pers_fte_onderwijsgevend.head(30)
# Out:
#    BRIN NUMMER               FUNCTIEGROEP  FTE'S 2012  FTE'S 2013  FTE'S 2014
# 1         16AH  Onderwijsgevend personeel     10.0345      9.1019     10.2489
# 3         16BX  Onderwijsgevend personeel      3.7861      3.7830      3.7830
# 6         16DJ  Onderwijsgevend personeel      4.0894      4.6451      4.7808
# 8         16HI  Onderwijsgevend personeel      8.0842      6.7786      6.6984
# 10        16MA  Onderwijsgevend personeel     25.5978     23.5600     25.1079
# 13        16NR  Onderwijsgevend personeel     11.4994     15.2640     12.1381
# 15        16UA  Onderwijsgevend personeel      9.5409      9.4522      8.4784
# 18        16WN  Onderwijsgevend personeel      5.5566      4.7336      3.7220
# 21        16XQ  Onderwijsgevend personeel     16.0790     15.7023     18.3906
# 24        16YK  Onderwijsgevend personeel      6.1597      6.1597      6.2530
# 26        16ZQ  Onderwijsgevend personeel      6.2380      5.2793      5.1318
# 28        17AE  Onderwijsgevend personeel      4.4846      3.6311      3.4090
# 30        17BC  Onderwijsgevend personeel      6.7545      7.0826      5.7016
# 33        17BL  Onderwijsgevend personeel      4.5412      4.5176      3.9802
# 35        17BU  Onderwijsgevend personeel      5.5266      4.9844      5.0788
# 37        17CN  Onderwijsgevend personeel      5.0217      3.8520      2.6228
# 40        17CW  Onderwijsgevend personeel      4.7239      5.7080      5.1585
# 43        17DG  Onderwijsgevend personeel     11.4389      7.5138      8.3674
# 45        17DQ  Onderwijsgevend personeel     18.9184     18.3951     21.4617
# 47        17EJ  Onderwijsgevend personeel      8.5377      7.6842      6.8307
# 49        17FD  Onderwijsgevend personeel      2.1581      1.1581      2.0000
# 51        17FU  Onderwijsgevend personeel      8.6748      8.0613      8.1245
# 53        17JD  Onderwijsgevend personeel      2.8535      1.8535      2.8535
# 55        17KM  Onderwijsgevend personeel      6.4150      5.4880      4.1094
# 58        18HB  Onderwijsgevend personeel      6.3098      5.2961      6.4636
# 61        21PS  Onderwijsgevend personeel     16.7156     16.2891     15.2225
# 63        23RM  Onderwijsgevend personeel     24.9982     25.0395     23.5223
# 66        24ED  Onderwijsgevend personeel      9.7463      8.1961      8.6428
# 69        30AG  Onderwijsgevend personeel      3.1266      4.6343      4.1707
# 71        13TY  Onderwijsgevend personeel     13.1747     13.1695     12.9296

# %%
leerlingen1213 = pd.read_excel("01. Leerlingen bo - leerlinggewicht en schoolgewicht- 2012-2013.xls")
leerlingen1213_tot = leerlingen1213[['BRIN NUMMER', 'TOTAAL']]
leerlingen1213_tot = leerlingen1213_tot.rename(columns = {'TOTAAL':'TOTAAL 2012-2013'})
leerlingen1314 = pd.read_excel("01. Leerlingen bo - leerlinggewicht en schoolgewicht- 2013-2014.xls")
leerlingen1314_tot = leerlingen1314[['BRIN NUMMER', 'TOTAAL']]
leerlingen1314_tot = leerlingen1314_tot.rename(columns = {'TOTAAL':'TOTAAL 2013-2014'})
leerlingen1415 = pd.read_excel("01. Leerlingen bo - leerlinggewicht en schoolgewicht- 2014-2015.xls")
leerlingen1415_tot = leerlingen1415[['BRIN_NUMMER', 'TOTAAL']]
leerlingen1415_tot = leerlingen1415_tot.rename(columns = {'TOTAAL':'TOTAAL 2014-2015'})
leerlingen1415_tot = leerlingen1415_tot.rename(columns = {'BRIN_NUMMER':'BRIN NUMMER'})

# %%
leerlingen_tot = pd.merge(pd.merge(leerlingen1213_tot,leerlingen1314_tot,on='BRIN NUMMER'),leerlingen1415_tot,on='BRIN NUMMER')
leerlingen_tot.head()
# Out:
#   BRIN NUMMER  TOTAAL 2012-2013  TOTAAL 2013-2014  TOTAAL 2014-2015
# 0        00AP                94                96                88
# 1        00AR               150               143               141
# 2        00AV                58                58                59
# 3        00AZ                77                79               133
# 4        00BA               117               113               106

# %%
fte_leerlingen = pd.merge(leerlingen_tot, pers_fte_onderwijsgevend,on='BRIN NUMMER')
fte_leerlingen = fte_leerlingen.drop('FUNCTIEGROEP', axis=1)
fte_leerlingen.head()
# Out:
#   BRIN NUMMER  TOTAAL 2012-2013  TOTAAL 2013-2014  TOTAAL 2014-2015  \
# 0        00AP                94                96                88
# 1        00AR               150               143               141
# 2        00AV                58                58                59
# 3        00AZ                77                79               133
# 4        00BA               117               113               106
#
#    FTE'S 2012  FTE'S 2013  FTE'S 2014
# 0      3.6178      4.0381      4.1248
# 1      7.8546      7.9405      8.0966
# 2      3.7080      4.0251      4.6444
# 3     10.9558      8.6015      8.0380
# 4      6.3295      7.0346      6.3348

# %%
fte_leerlingen['Leerlingen per fte 2012-2013'] = fte_leerlingen['TOTAAL 2012-2013'] / fte_leerlingen["FTE'S 2012"]
fte_leerlingen['Leerlingen per fte 2013-2014'] = fte_leerlingen['TOTAAL 2013-2014'] / fte_leerlingen["FTE'S 2013"]
fte_leerlingen['Leerlingen per fte 2014-2015'] = fte_leerlingen['TOTAAL 2014-2015'] / fte_leerlingen["FTE'S 2014"]

fte_leerlingen.head(20)
# Out:
#    BRIN NUMMER  TOTAAL 2012-2013  TOTAAL 2013-2014  TOTAAL 2014-2015  \
# 0         00AP                94                96                88
# 1         00AR               150               143               141
# 2         00AV                58                58                59
# 3         00AZ                77                79               133
# 4         00BA               117               113               106
# 5         00BB               109               103                98
# 6         00BS               127               127               128
# 7         00BW                95                86                98
# 8         00CD               191               179               160
# 9         00CG               371               378               389
# 10        00CS                87                92                78
# 11        00CU                71                75                71
# 12        00CV                62                56                41
# 13        00DA                75                69                73
# 14        00DD               284               280               296
# 15        00DM               159               161               157
# 16        00DN               155               167               153
# 17        00DO               160               142               157
# 18        00DW               183               176               170
# 19        00DX               170               175               173
#
#     FTE'S 2012  FTE'S 2013  FTE'S 2014  Leerlingen per fte 2012-2013  \
# 0       3.6178    4.038100      4.1248                     25.982641
# 1       7.8546    7.940500      8.0966                     19.097090
# 2       3.7080    4.025100      4.6444                     15.641855
# 3      10.9558    8.601500      8.0380                      7.028241
# 4       6.3295    7.034600      6.3348                     18.484872
# 5       9.0515   10.905791      6.4256                     12.042203
# 6       5.7147    5.081900      5.0669                     22.223389
# 7      10.9904    9.740900      8.6284                      8.643907
# 8       8.6081    9.603000      7.0035                     22.188404
# 9      21.9891   19.046900     19.3149                     16.871996
# 10      4.5741    5.079800      4.7215                     19.020135
# 11      5.0752    5.966800      5.2424                     13.989596
# 12      3.4500    3.910000      4.7900                     17.971014
# 13      7.0893    8.586100      5.7868                     10.579324
# 14     16.2343   14.879800     14.2737                     17.493825
# 15      9.6094    8.134200      5.9201                     16.546298
# 16      6.4234    6.886400      7.3810                     24.130523
# 17      6.5405    6.790500      6.8155                     24.462962
# 18     11.5870   11.514400     12.4794                     15.793562
# 19     10.1341    8.869500      9.6490                     16.775047
#
#     Leerlingen per fte 2013-2014  Leerlingen per fte 2014-2015
# 0                      23.773557                     21.334368
# 1                      18.008942                     17.414717
# 2                      14.409580                     12.703471
# 3                       9.184445                     16.546405
# 4                      16.063458                     16.732967
# 5                       9.444523                     15.251494
# 6                      24.990653                     25.261995
# 7                       8.828753                     11.357842
# 8                      18.640008                     22.845720
# 9                      19.845749                     20.139892
# 10                     18.110949                     16.520174
# 11                     12.569552                     13.543415
# 12                     14.322251                      8.559499
# 13                      8.036245                     12.614917
# 14                     18.817457                     20.737440
# 15                     19.792973                     26.519822
# 16                     24.250697                     20.728899
# 17                     20.911568                     23.035727
# 18                     15.285208                     13.622450
# 19                     19.730537                     17.929319

# %%
fte_leerlingen_av = fte_leerlingen[['BRIN NUMMER', 'Leerlingen per fte 2012-2013', 'Leerlingen per fte 2013-2014', 'Leerlingen per fte 2014-2015']]
fte_leerlingen_av.head()
# Out:
#   BRIN NUMMER  Leerlingen per fte 2012-2013  Leerlingen per fte 2013-2014  \
# 0        00AP                     25.982641                     23.773557
# 1        00AR                     19.097090                     18.008942
# 2        00AV                     15.641855                     14.409580
# 3        00AZ                      7.028241                      9.184445
# 4        00BA                     18.484872                     16.063458
#
#    Leerlingen per fte 2014-2015
# 0                     21.334368
# 1                     17.414717
# 2                     12.703471
# 3                     16.546405
# 4                     16.732967

# %%
fte_cito = pd.merge(scholenoverzicht_citoscores, fte_leerlingen_av, on='BRIN NUMMER')
fte_cito.head(100)
# Out:
#    BRIN NUMMER                                     naam  \
# 0         07OL          Rotterdamse Schoolvereniging II
# 1         08XI       Rotterdamse Schoolvereniging Noord
# 2         16KZ              Professor Wassenberghschool
# 3         03HI           de Gereformeerde b.s. Rehoboth
# 4         03BA         Basisschool Jan van Rijckenborgh
# 5         09JG   Gereformeerde basisschool Joh. Calvijn
# 6         03JD             Basisschool Pieter Jongeling
# 7         06EN             Geref. basisschool Het Baken
# 8         04FM                 Capelse Schoolvereniging
# 9         00AP                Basisschool De Schanskorf
# 10        06EK                    g.b.s. R.J. Damschool
# 11        03KR          Geref. basisschool De Lichtbron
# 12        07LD     n.b.b.s. Leeuwarder Schoolvereniging
# 13        08CJ           Eerste Leidse Schoolvereniging
# 14        10HO                    Basisschool Windekind
# 15        07KK                   Geref.b.s. De Handpalm
# 16        17FD                    o.b.s. Mr Halmaschool
# 17        00GU                     a.b.b.s. De Reinboge
# 18        03HS  Gereformeerde basisschool Oranje Nassau
# 19        08CF              Delftsche Schoolvereeniging
# 20        08NU      De Buitenveldertse Montessorischool
# 21        15ME                     o.b.s. It Fiifde Ste
# 22        06YF                  Basisschool 't Holthuus
# 23        13EN                       basisschool Buurse
# 24        05TS                       c.b.s. De VeenSter
# 25        30AG                          obs Delftlanden
# 26        07IL                  c.b.s. Staetlansskoalle
# 27        06IP                    Basisschool De Vonder
# 28        04DE    Gereformeerde basisschool De Triangel
# 29        04DE    Gereformeerde basisschool De Triangel
# ..         ...                                      ...
# 70        17MJ               basisschool De Leidse Hout
# 71        17MJ               basisschool De Leidse Hout
# 72        17MJ               basisschool De Leidse Hout
# 73        17MJ               basisschool De Leidse Hout
# 74        17MJ               basisschool De Leidse Hout
# 75        17MJ               basisschool De Springplank
# 76        17MJ               basisschool De Springplank
# 77        17MJ               basisschool De Springplank
# 78        17MJ               basisschool De Springplank
# 79        17MJ               basisschool De Springplank
# 80        17MJ               basisschool De Springplank
# 81        17MJ               basisschool De Springplank
# 82        17MJ               basisschool De Springplank
# 83        08CQ           Basisschool G.J. van den Brink
# 84        21NI            geref. basisschool De Fontein
# 85        17LQ                      c.b.s. De Hoeksteen
# 86        19NM                        Marcellinusschool
# 87        19NM                        Marcellinusschool
# 88        19NM                        Marcellinusschool
# 89        19NM                        Marcellinusschool
# 90        19NM                        Marcellinusschool
# 91        19NM                        Marcellinusschool
# 92        19NM                        Marcellinusschool
# 93        19NM                        Marcellinusschool
# 94        19NM                 Paus Joannes/Marcellinus
# 95        19NM                 Paus Joannes/Marcellinus
# 96        19NM                 Paus Joannes/Marcellinus
# 97        19NM                 Paus Joannes/Marcellinus
# 98        19NM                 Paus Joannes/Marcellinus
# 99        19NM                 Paus Joannes/Marcellinus
#
#                          adres postcode                  plaats  \
# 0            Stuart Millpad 84  3076 RK               Rotterdam
# 1         Schiedamsesingel 155  3012 BB               Rotterdam
# 2                Ieborchpaed 6  9081 AR                  Lekkum
# 3          Pompenburgsingel 30  3135 PS             Vlaardingen
# 4         's-Gravesandelaan 15  1222 SX               Hilversum
# 5              Froukemaheerd 1  9736 RA               Groningen
# 6          Zijpendaalseweg 163  6814 CJ                  Arnhem
# 7             Stuurboordlaan 1  9934 JN                Delfzijl
# 8                 Alkenlaan 91  2903 EB  Capelle aan den IJssel
# 9                Overwater 1-3  2715 BT              Zoetermeer
# 10          Langelandsterweg 1  9982 BC         Uithuizermeeden
# 11      Donker Curtiusstraat 2  9602 PK               Hoogezand
# 12           Jelsumerstraat 10  8917 EN              Leeuwarden
# 13           P.C. Hooftlaan 12  2332 AX                  Leiden
# 14  Van Weerden Poelmanstr 192  6417 ES                 Heerlen
# 15      Prins Bernhardstraat 3  9965 RA                   Leens
# 16            Oosterwijk WZ 56  7885 TN         Nieuw-Dordrecht
# 17           Greate Buorren 45  8732 EE                 Kubaard
# 18      Linthorst Homanloane 5  9288 BA           Kootstertille
# 19             Koningsplein 83  2611 XG                   Delft
# 20             Sandenburch 1-3  1082 GN               Amsterdam
# 21                 Tolvepaed 4  8468 BJ            Haskerdijken
# 22             Ot en Sienpad 9  6852 EG                 Huissen
# 23                 de Noor 101  7481 RL             Haaksbergen
# 24                 Kerklaan 12  9341 AV              Veenhuizen
# 25                 Zandzoom 19  7814 VH                   Emmen
# 26               Smidsreed 6-8  8804 NH                    Tzum
# 27                Kerkvonder 3  6599 AK         Ven-Zelderheide
# 28           Rode Kruislaan 78  9728 CX               Groningen
# 29           Rode Kruislaan 78  9728 CX               Groningen
# ..                         ...      ...                     ...
# 70        Adriaan Pauwstraat 1  2334 CG                  Leiden
# 71        Adriaan Pauwstraat 1  2334 CG                  Leiden
# 72        Adriaan Pauwstraat 1  2334 CG                  Leiden
# 73        Adriaan Pauwstraat 1  2334 CG                  Leiden
# 74        Adriaan Pauwstraat 1  2334 CG                  Leiden
# 75              Bonaireplein 4  2315 HG                  Leiden
# 76              Bonaireplein 4  2315 HG                  Leiden
# 77              Bonaireplein 4  2315 HG                  Leiden
# 78              Bonaireplein 4  2315 HG                  Leiden
# 79              Bonaireplein 4  2315 HG                  Leiden
# 80              Bonaireplein 4  2315 HG                  Leiden
# 81              Bonaireplein 4  2315 HG                  Leiden
# 82              Bonaireplein 4  2315 HG                  Leiden
# 83         Oude Eekmolenweg 30  6706 AP              Wageningen
# 84             Molenstraat 17a  9285 PA              Buitenpost
# 85     Dr G van Schouwenlaan 2  8441 CA              Heerenveen
# 86            Saffierstraat 30  7548 CD                Enschede
# 87            Saffierstraat 30  7548 CD                Enschede
# 88            Saffierstraat 30  7548 CD                Enschede
# 89            Saffierstraat 30  7548 CD                Enschede
# 90            Saffierstraat 30  7548 CD                Enschede
# 91            Saffierstraat 30  7548 CD                Enschede
# 92            Saffierstraat 30  7548 CD                Enschede
# 93            Saffierstraat 30  7548 CD                Enschede
# 94         Floraparkstraat 155  7531 XG                Enschede
# 95         Floraparkstraat 155  7531 XG                Enschede
# 96         Floraparkstraat 155  7531 XG                Enschede
# 97         Floraparkstraat 155  7531 XG                Enschede
# 98         Floraparkstraat 155  7531 XG                Enschede
# 99         Floraparkstraat 155  7531 XG                Enschede
#
#                   gemeente      provincie               denominatie  \
# 0                Rotterdam   Zuid-Holland        Algemeen Bijzonder
# 1                Rotterdam   Zuid-Holland        Algemeen Bijzonder
# 2               Leeuwarden      Friesland                  Openbaar
# 3              Vlaardingen   Zuid-Holland  Gereformeerd Vrijgemaakt
# 4                Hilversum  Noord-Holland        Algemeen Bijzonder
# 5                Groningen      Groningen  Gereformeerd Vrijgemaakt
# 6                   Arnhem     Gelderland  Gereformeerd Vrijgemaakt
# 7                 Delfzijl      Groningen  Gereformeerd Vrijgemaakt
# 8   Capelle aan den IJssel   Zuid-Holland        Algemeen Bijzonder
# 9               Zoetermeer   Zuid-Holland  Gereformeerd Vrijgemaakt
# 10                Eemsmond      Groningen  Gereformeerd Vrijgemaakt
# 11     Hoogezand-Sappemeer      Groningen  Gereformeerd Vrijgemaakt
# 12              Leeuwarden      Friesland        Algemeen Bijzonder
# 13                  Leiden   Zuid-Holland        Algemeen Bijzonder
# 14                 Heerlen        Limburg           Rooms-Katholiek
# 15                De Marne      Groningen  Gereformeerd Vrijgemaakt
# 16                   Emmen        Drenthe                  Openbaar
# 17          Littenseradiel      Friesland        Algemeen Bijzonder
# 18           Achtkarspelen      Friesland  Gereformeerd Vrijgemaakt
# 19                   Delft   Zuid-Holland        Algemeen Bijzonder
# 20               Amsterdam  Noord-Holland        Algemeen Bijzonder
# 21         De Friese Meren      Friesland                  Openbaar
# 22              Lingewaard     Gelderland        Algemeen Bijzonder
# 23             Haaksbergen     Overijssel           Rooms-Katholiek
# 24             Noordenveld        Drenthe   Protestants-Christelijk
# 25                   Emmen        Drenthe                  Openbaar
# 26           Franekeradeel      Friesland   Protestants-Christelijk
# 27                  Gennep        Limburg           Rooms-Katholiek
# 28               Groningen      Groningen  Gereformeerd Vrijgemaakt
# 29               Groningen      Groningen  Gereformeerd Vrijgemaakt
# ..                     ...            ...                       ...
# 70                  Leiden   Zuid-Holland   Protestants-Christelijk
# 71                  Leiden   Zuid-Holland   Protestants-Christelijk
# 72                  Leiden   Zuid-Holland   Protestants-Christelijk
# 73                  Leiden   Zuid-Holland   Protestants-Christelijk
# 74                  Leiden   Zuid-Holland   Protestants-Christelijk
# 75                  Leiden   Zuid-Holland   Protestants-Christelijk
# 76                  Leiden   Zuid-Holland   Protestants-Christelijk
# 77                  Leiden   Zuid-Holland   Protestants-Christelijk
# 78                  Leiden   Zuid-Holland   Protestants-Christelijk
# 79                  Leiden   Zuid-Holland   Protestants-Christelijk
# 80                  Leiden   Zuid-Holland   Protestants-Christelijk
# 81                  Leiden   Zuid-Holland   Protestants-Christelijk
# 82                  Leiden   Zuid-Holland   Protestants-Christelijk
# 83              Wageningen     Gelderland        Algemeen Bijzonder
# 84           Achtkarspelen      Friesland  Gereformeerd Vrijgemaakt
# 85              Heerenveen      Friesland   Protestants-Christelijk
# 86                Enschede     Overijssel           Rooms-Katholiek
# 87                Enschede     Overijssel           Rooms-Katholiek
# 88                Enschede     Overijssel           Rooms-Katholiek
# 89                Enschede     Overijssel           Rooms-Katholiek
# 90                Enschede     Overijssel           Rooms-Katholiek
# 91                Enschede     Overijssel           Rooms-Katholiek
# 92                Enschede     Overijssel           Rooms-Katholiek
# 93                Enschede     Overijssel           Rooms-Katholiek
# 94                Enschede     Overijssel           Rooms-Katholiek
# 95                Enschede     Overijssel           Rooms-Katholiek
# 96                Enschede     Overijssel           Rooms-Katholiek
# 97                Enschede     Overijssel           Rooms-Katholiek
# 98                Enschede     Overijssel           Rooms-Katholiek
# 99                Enschede     Overijssel           Rooms-Katholiek
#
#                                visie SCORE_2012 SCORE_2013 SCORE_2014  \
# 0                           Regulier      546.4      543.5      545.2
# 1                           Regulier      540.5      543.2      541.2
# 2                           Regulier        535      532.8      521.5
# 3                           Regulier      535.7      537.2      535.1
# 4                           Regulier      540.2      545.8      531.8
# 5                           Regulier      539.3      543.6      540.1
# 6                           Regulier      539.7      538.4      536.8
# 7                           Regulier      537.3      538.3      532.2
# 8                           Regulier      539.9      543.2      538.9
# 9                           Regulier        539      538.1      531.8
# 10                          Regulier      531.5        533      533.2
# 11                          Regulier      533.8      530.3      535.8
# 12                          Regulier        536      541.7      538.1
# 13                          Regulier      539.1      540.6      538.9
# 14                          Regulier      540.4      538.8      539.5
# 15                          Regulier      535.9      536.5      530.9
# 16                          Regulier                            540.3
# 17      Gecertificeerde Daltonschool      539.3      534.6      536.8
# 18                          Regulier      538.1      536.5      537.5
# 19                          Regulier      541.6      540.7      540.9
# 20  Gecertificeerde Montessorischool      540.8      534.8      540.5
# 21                          Regulier      536.9      535.1      541.3
# 22                          Regulier      535.1      537.4      530.8
# 23                          Regulier      533.9      541.6      534.8
# 24      Gecertificeerde Daltonschool      536.8      536.4      537.1
# 25                          Regulier      532.5        529      538.8
# 26                          Regulier      530.9      532.4      538.3
# 27                          Regulier      536.4      536.6      534.9
# 28                          Regulier      540.3      528.3      533.8
# 29                          Regulier      540.3      528.3      533.8
# ..                               ...        ...        ...        ...
# 70                          Regulier      539.2      538.8      541.7
# 71                          Regulier      539.2      538.8      541.7
# 72                          Regulier      539.2      538.8      541.7
# 73                          Regulier      539.2      538.8      541.7
# 74                          Regulier      539.2      538.8      541.7
# 75                          Regulier      536.3      533.7      529.5
# 76                          Regulier      536.3      533.7      529.5
# 77                          Regulier      536.3      533.7      529.5
# 78                          Regulier      536.3      533.7      529.5
# 79                          Regulier      536.3      533.7      529.5
# 80                          Regulier      536.3      533.7      529.5
# 81                          Regulier      536.3      533.7      529.5
# 82                          Regulier      536.3      533.7      529.5
# 83                          Regulier        540      542.6      536.6
# 84                          Regulier      542.6      542.1      533.8
# 85                          Regulier        538      538.4      532.7
# 86                          Regulier      537.6      533.4      538.9
# 87                          Regulier      537.6      533.4      538.9
# 88                          Regulier      537.6      533.4      538.9
# 89                          Regulier      537.6      533.4      538.9
# 90                          Regulier      537.6      533.4      538.9
# 91                          Regulier      537.6      533.4      538.9
# 92                          Regulier      537.6      533.4      538.9
# 93                          Regulier      537.6      533.4      538.9
# 94                          Regulier      533.7      536.8      528.7
# 95                          Regulier      533.7      536.8      528.7
# 96                          Regulier      533.7      536.8      528.7
# 97                          Regulier      533.7      536.8      528.7
# 98                          Regulier      533.7      536.8      528.7
# 99                          Regulier      533.7      536.8      528.7
#
#     Leerlingen per fte 2012-2013  Leerlingen per fte 2013-2014  \
# 0                      19.827877                     20.093074
# 1                      17.270137                     19.417168
# 2                      25.194205                     22.782349
# 3                      20.540911                     20.425671
# 4                      19.320171                     14.965382
# 5                      23.202823                     22.167234
# 6                      21.836751                     22.716599
# 7                      15.093884                     15.203005
# 8                      19.297080                     17.811025
# 9                      25.982641                     23.773557
# 10                     23.315169                     20.644043
# 11                     18.209586                     20.052940
# 12                     19.848828                     18.262474
# 13                     17.088230                     15.643250
# 14                     20.733008                     20.437242
# 15                     19.066220                     19.023608
# 16                     12.047634                     20.723599
# 17                     11.552599                     10.744986
# 18                     22.862369                     21.177773
# 19                     17.859383                     17.467106
# 20                     18.743018                     17.369471
# 21                     14.028638                     12.058484
# 22                     14.717473                     13.108847
# 23                     22.146600                     21.562681
# 24                     18.775510                     10.229286
# 25                     23.028210                     12.731157
# 26                     22.255451                     23.678914
# 27                     10.604454                     10.864613
# 28                     12.796829                     11.546084
# 29                     12.796829                     11.546084
# ..                           ...                           ...
# 70                     11.703141                      6.240803
# 71                      6.420009                     11.594755
# 72                      6.420009                     11.594755
# 73                      6.420009                      6.240803
# 74                      6.420009                      6.240803
# 75                     11.703141                     11.594755
# 76                     11.703141                     11.594755
# 77                     11.703141                      6.240803
# 78                     11.703141                      6.240803
# 79                      6.420009                     11.594755
# 80                      6.420009                     11.594755
# 81                      6.420009                      6.240803
# 82                      6.420009                      6.240803
# 83                     20.918566                     20.093290
# 84                     18.930344                     24.547338
# 85                     19.375216                     18.005176
# 86                     15.064359                     17.596535
# 87                     15.064359                     17.596535
# 88                     15.064359                      4.491423
# 89                     15.064359                      4.491423
# 90                      4.020736                     17.596535
# 91                      4.020736                     17.596535
# 92                      4.020736                      4.491423
# 93                      4.020736                      4.491423
# 94                     15.064359                     17.596535
# 95                     15.064359                     17.596535
# 96                     15.064359                      4.491423
# 97                     15.064359                      4.491423
# 98                      4.020736                     17.596535
# 99                      4.020736                     17.596535
#
#     Leerlingen per fte 2014-2015
# 0                      19.976239
# 1                      20.138852
# 2                      23.824626
# 3                      18.835182
# 4                      15.344614
# 5                      20.613065
# 6                      21.490251
# 7                      15.414571
# 8                      18.073904
# 9                      21.334368
# 10                     22.013208
# 11                     18.451859
# 12                     18.545900
# 13                     15.653307
# 14                     20.678821
# 15                     19.392837
# 16                      9.500000
# 17                     10.369364
# 18                     20.696460
# 19                     17.513993
# 20                     17.840448
# 21                     11.404986
# 22                     21.027931
# 23                     21.526539
# 24                     12.322682
# 25                     13.187235
# 26                     17.557136
# 27                     10.118006
# 28                      9.562765
# 29                      7.538530
# ..                           ...
# 70                      7.508038
# 71                     11.931090
# 72                      7.508038
# 73                     11.931090
# 74                      7.508038
# 75                     11.931090
# 76                      7.508038
# 77                     11.931090
# 78                      7.508038
# 79                     11.931090
# 80                      7.508038
# 81                     11.931090
# 82                      7.508038
# 83                     19.925146
# 84                     20.796525
# 85                     21.191198
# 86                     15.693340
# 87                      4.079135
# 88                     15.693340
# 89                      4.079135
# 90                     15.693340
# 91                      4.079135
# 92                     15.693340
# 93                      4.079135
# 94                     15.693340
# 95                      4.079135
# 96                     15.693340
# 97                      4.079135
# 98                     15.693340
# 99                      4.079135
#
# [100 rows x 15 columns]

# %% [markdown]
# ## Correlatie tussen cito score en inkomen

# %%
## Correlatie tussen cito score en inkomen

cito_fte_corr12 = fte_cito[['SCORE_2012','Leerlingen per fte 2012-2013']]
cito_fte_corr12.plot(kind='scatter', marker='s', logy=True, figsize=(7, 5), x = 'SCORE_2012', y = 'Leerlingen per fte 2012-2013', title= 'Leerlingen per fte vs Cito score')

# Correlation
print 'Pearson Correlation (R)'
cito_fte_corr12.corr(method='pearson')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e7f0057dc8fa> in <module>()
#       2
#       3 cito_fte_corr12 = fte_cito[['SCORE_2012','Leerlingen per fte 2012-2013']]
# ----> 4 cito_fte_corr12.plot(kind='scatter', marker='s', logy=True, figsize=(7, 5), x = 'SCORE_2012', y = 'Leerlingen per fte 2012-2013', title= 'Leerlingen per fte vs Cito score')
#       5
#       6 # Correlation
#
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3735                           fontsize=fontsize, colormap=colormap, table=table,
#    3736                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3737                           sort_columns=sort_columns, **kwds)
#    3738     __call__.__doc__ = plot_frame.__doc__
#    3739
#
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2609                  yerr=yerr, xerr=xerr,
#    2610                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2611                  **kwds)
#    2612
#    2613
#
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2436         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2437
# -> 2438     plot_obj.generate()
#    2439     plot_obj.draw()
#    2440     return plot_obj.result
#
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#    1023         self._compute_plot_data()
#    1024         self._setup_subplots()
# -> 1025         self._make_plot()
#    1026         self._add_table()
#    1027         self._make_legend()
#
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _make_plot(self)
#    1595         else:
#    1596             label = None
# -> 1597         scatter = ax.scatter(data[x].values, data[y].values, c=c_values,
#    1598                              label=label, cmap=cmap, **self.kwds)
#    1599         if cb:
#
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1343         res = cache.get(item)
#    1344         if res is None:
# -> 1345             values = self._data.get(item)
#    1346             res = self._box_item_values(item, values)
#    1347             cache[item] = res
#
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3223
#    3224             if not isnull(item):
# -> 3225                 loc = self.items.get_loc(item)
#    3226             else:
#    3227                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/dylan/anaconda2/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
# -> 1878                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1879
#    1880         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 'SCORE_2012'
