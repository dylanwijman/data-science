# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Grading scheme\n",
#     "\n",
#     "Q1: 2\n",
#     "Q2: 2\n",
#     "Q3 1-4 no points\n",
#     "Q3.5 1-5, 1 point for each subquestion\n",
#     "Q4 3 points\n",
#     "\n",
#     "Bonus: Zipf 3 points Bonus2: 5 points\n",
#     "\n",
#     "Maximum = 12 points\n",
#     "\n",
#     "### Make it easy for yourself: for each subquestion score with 3-valued logic: 0, .5 or 1. Then add.\n",
#     "\n",
#     "Don't be too super strict, but don't be too lenient as well."
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Python Recap Exam\n",
#     "\n",
#     "This exam is meant to test how fluent or how rusty you are in Python. \n",
#     "We do some simple things working with lists, counting things, and doing a bit of basic statistics.\n",
#     "You may not remember everything at one. That is no problem, if you can reasonably fast find it back using Python's reference.\n",
#     "\n",
#     "Also, don't forget the great help that IPython can give you: TAB and ?"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "#### Start with running the following code."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 4,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "[u'ASIAN', u'EXPORTERS', u'FEAR', u'DAMAGE', u'FROM']"
#       ]
#      },
#      "execution_count": 4,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "import re,pprint,nltk\n",
#     "from __future__ import division\n",
#     "from nltk.corpus import reuters \n",
#     "# make a corpus of all words in the test files\n",
#     "testIDs= [w for w in reuters.fileids() if w.startswith('test')]\n",
#     "testWords=reuters.words(testIDs)\n",
#     "testWords[:5]\n",
#     " "
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "### Questions"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "Make the questions. \n",
#     "Answer them  in the code block after the question. \n",
#     "\n",
#     "Reuse variables that you have defined in earlier questions in later questions."
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "\n",
#     "\n",
#     "(1) How many words/tokens are there in testWords? And how many unique tokens/words? What is the average frequency of a word?\n",
#     "Define a variable for each subquestion.\n",
#     "Then print out all variables at once. Use this style for the other exercises as well.\n",
#     "So something like:\n",
#     "```\n",
#     "NumWords = ...\n",
#     "NumUnique = ...\n",
#     "AvgFreq = ....\n",
#     "NumWords, NumUnique, AvgFreq\n",
#     "```\n",
#     "Or even better with a nicely formatted string."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 5,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "(467205, 22337, 20.91619286385817)"
#       ]
#      },
#      "execution_count": 5,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "NumWords = len(testWords)\n",
#     "NumUnique = len(set(testWords))\n",
#     "AvgFreq = NumWords / NumUnique\n",
#     "NumWords, NumUnique, AvgFreq"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "(2) How many bigrams are there in testWords? How many unique ones? What is the average bigram frequency? Explain the difference of the last two numbers with the numbers in the previous question. \n",
#     "Make it easy for yourself. Just use the most \"dumb\" definition of bigram."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 6,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "(467204, 155763, 2.9994542991596207)"
#       ]
#      },
#      "execution_count": 6,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "NumBigrams = NumWords -1\n",
#     "Bigrams = [(testWords[i],testWords[i+1]) for i in range(len(testWords)-1)]\n",
#     "NumUniqueBigrams=len(set(Bigrams))\n",
#     "NumBigrams,NumUniqueBigrams,NumBigrams/NumUniqueBigrams"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "(3)  There are quite some tokens in testWords which are not really \"words\".\n",
#     "\n",
#     "Use [regular expressions](https://docs.python.org/2/library/re.html) and use the list of english stopwords which can be obtained as follows:\n",
#     "\n",
#     "```\n",
#     "from nltk.corpus import stopwords\n",
#     "# test\n",
#     "stopwords.words('english')[:20]\n",
#     "```\n",
#     "\n",
#     "Don't display too many digits behind the comma: use the `round()` function to control that.\n",
#     "\n",
#     "3.1. Create the list of all \"punctuation tokens\" in testWords.\n",
#     "\n",
#     "3.2. Create the list of all \"stopword tokens\" in testWords. Use NLTK's english stopword list.\n",
#     "\n",
#     "3.3. Compute the percentage of all tokens in testWords that is a punctuation and the percentage of all tokens in testWords that is a stopword.\n",
#     "\n",
#     "3.4. How many (as a percentage) of the UNIQUE tokens in testWords is a punctuation? How many a stopword?\n",
#     "\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 7,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "[14.818, 0.322, 22.632, 0.546]"
#       ]
#      },
#      "execution_count": 7,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "from nltk.corpus import stopwords\n",
#     "Puncts = [w for w in testWords if  re.match(r'\\W+',w)]\n",
#     "StopWords = [ w for w in testWords if  w in stopwords.words('english')]\n",
#     "PunctPerc =  len(Puncts) / len(testWords) \n",
#     "StopPerc =  len(StopWords)/ len(testWords) \n",
#     "UPunctPerc =   len(set(Puncts)) / len(set(testWords))\n",
#     "UStopPerc =   len(set(StopWords)) / len(set(testWords))\n",
#     "\n",
#     "[ round(i*100,3) for i in (PunctPerc,UPunctPerc,StopPerc,UStopPerc)]\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 8,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "[(u'.).', 1),\n",
#        " (u')-', 1),\n",
#        " (u'.........--........', 1),\n",
#        " (u'$', 1),\n",
#        " (u'---', 4),\n",
#        " (u\"'&\", 1),\n",
#        " (u'?,\"', 1),\n",
#        " (u'>,', 180),\n",
#        " (u'),', 108),\n",
#        " (u'>.', 108)]"
#       ]
#      },
#      "execution_count": 8,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "# Show the top ten most occuring punctuation tokens\n",
#     "nltk.FreqDist(Puncts).items()[:10]"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "3.5 We will now start counting _how often_ words appear in the list `testWords`. Counting is a very important and often used tool. It is _expensive_ as it involves sorting.\n",
#     "\n",
#     "There are several ways to do counting, and we look at a few of them:\n",
#     "\n",
#     "\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 9,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "(15048, 1, [u'the', u'the', u'the', u'the', u'the'])"
#       ]
#      },
#      "execution_count": 9,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "# The number of times the word \"the\" occurs\n",
#     "the = [x for x in testWords if x=='the']\n",
#     "len(the), len(set(the)), the[:5]"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 10,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "15048"
#       ]
#      },
#      "execution_count": 10,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "# Each list has a count method, which is ideal for counting\n",
#     "testWords.count('the')"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 11,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "(Counter({'blue': 3, 'red': 2, 'yellow': 1}), 3)"
#       ]
#      },
#      "execution_count": 11,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "# This trick counts all items in one go and yields a dictionary\n",
#     "from collections import Counter\n",
#     "z = ['blue', 'red', 'blue', 'yellow', 'blue', 'red']\n",
#     "Counter(z), Counter(z)['blue']\n",
#     " "
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [],
#    "source": [
#     "# with NLTK we can make a similar datastructure\n",
#     "testfd= nltk.FreqDist(testWords)\n",
#     "testfd.items()[:5]"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "3.5.1 Use `set()` and dict comprehension to create a dict like `testfd` using the `.count()` method\n",
#     "\n",
#     "3.5.2 You now have 3 ways to make a wordcount dictionary. Use the timing functions to see which one is the fastest.\n",
#     "\n",
#     "3.5.3 Which percentage of the UNIQUE tokens in testWords is a hapax (i.e. occurs only once in testWords)?\n",
#     "\n",
#     "3.5.4 Which percentage of the   tokens in testWords is a hapax? \n",
#     "\n",
#     "3.5.5 Explain why the following test returns True: `len(testfd)==len(set(testWords))`"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 12,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [],
#    "source": [
#     "# 3.5.1 Use set() and dict comprehension to create a dict like testfd using the .count() method\n",
#     "## This is super slow, so we restrict to the first 100 words\n",
#     "testfd2 = { w:testWords.count(w) for w in set(testWords[:100])}\n",
#     "\n",
#     "#testfd == testfd2"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 13,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "CPU times: user 1.01 s, sys: 47.2 ms, total: 1.06 s\n",
#       "Wall time: 1.06 s\n",
#       "CPU times: user 1.03 s, sys: 44.4 ms, total: 1.08 s\n",
#       "Wall time: 1.08 s\n",
#       "CPU times: user 12.5 s, sys: 623 ms, total: 13.2 s\n",
#       "Wall time: 13.2 s\n",
#       "CPU times: user 12.5 s, sys: 646 ms, total: 13.2 s\n",
#       "Wall time: 13.3 s\n"
#      ]
#     }
#    ],
#    "source": [
#     "# 3.5.2 You now have 3 ways to make a wordcount dictionary. Use the timing functions to see which one is the fastest.\n",
#     "%time t1= nltk.FreqDist(testWords)\n",
#     "%time t2= Counter(testWords)\n",
#     "% time t3 = { w:testWords.count(w) for w in set(testWords[:20])}\n",
#     "%time t4 = { w:len([i for i in testWords if i==w]) for w in set(testWords[:20])}"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [],
#    "source": [
#     "# test if they are really the same\n",
#     "t1==t2"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 14,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "(0.019177876949090872, 0.4011281729865246)"
#       ]
#      },
#      "execution_count": 14,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "# 3.5.3 Which percentage of the UNIQUE tokens in testWords is a hapax (i.e. occurs only once in testWords)?\n",
#     "# 3.5.4 Which percentage of the tokens in testWords is a hapax?\n",
#     "testfd= nltk.FreqDist(testWords)\n",
#     "hapaxes=[w for (w,c) in testfd.items() if c==1]\n",
#     "hapaxPerc= len(hapaxes) / len( testWords)\n",
#     "UhapaxPerc = len(hapaxes) / len(set(testWords))\n",
#     "hapaxPerc,UhapaxPerc"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [],
#    "source": [
#     "# 3.5.5 Explain why the following test returns True: len(testfd)==len(set(testWords))\n",
#     "len(testfd), len(set(testWords)), \"because testfd is a dictionary with a key for each word in testWords\""
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "(4) Count the tokens in testWords. Make an estimate of the following probability: given a string t, if we draw an arbitrary  token from testWords, what is the chance that it equals t?\n",
#     "\n",
#     "Program it as a function prob(str).\n",
#     "Give an example of a high and of a low probability word.\n",
#     "\n",
#     "Does prob work on every input string?\n",
#     "\n",
#     "Test that 'the probabilities add up to 1'."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 15,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "0.0590276217078 0.0322085594118 0.0\n"
#      ]
#     },
#     {
#      "data": {
#       "text/plain": [
#        "0.9999999999998874"
#       ]
#      },
#      "execution_count": 15,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "def prob(string):\n",
#     "    return testfd[string] / NumWords\n",
#     "# tests  ('marx' does NOT occur in testWords)\n",
#     "print prob('.'),prob('the'), prob('marx')\n",
#     "# test\n",
#     "sum(prob(w) for w in testfd.keys())"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "(5) Suppose we have printed out testWords  using exactly one space between each two tokens. Suppose we have covered a wall with this string. Now you throw a dart missile on this wall. Assume that it always hits exactly one character, which is either a space (inserted by our printing process) or a character in a token.\n",
#     "\n",
#     "5.1 What is the probability that it hits a space?\n",
#     "\n",
#     "5.2 Define a function prob(n) which for integer n returns the probability that the missile hits a token of length n.\n",
#     "\n",
#     "5.3 Nicely print out a table of the form \"n,  prob(n)\" which for each n returns   prob(n). Format it well, and truncate numbers. Bonus points for those who make a plot.\n",
#     "\n",
#     "5.3.1 Write a good test which indicates that prob(n) works correctly.\n",
#     "\n",
#     "5.4 What is the probability that it hits a stopword?\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [],
#    "source": [
#     "# 5.1\n",
#     "def Charcount(wordlist): # add the number of spaces and the sum of the lengths of all words\n",
#     "    return (len(wordlist)-1   # the number of spaces equals the number of words minus 1\n",
#     "         + sum(len(w) for w in wordlist))  # sum all characters in all words\n",
#     "    \n",
#     "SpaceProb = (len(testWords)-1 )/   Charcount(testWords)\n",
#     "SpaceProb"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [],
#    "source": [
#     "# 5.2 & 5.3\n",
#     "\n",
#     "## What is inefficient about this code?\n",
#     "def prob(n,wordlist):\n",
#     "    charlengthdist=nltk.FreqDist([len(w) for w in wordlist])\n",
#     "    #print charlengthdist.tabulate()\n",
#     "    return (n*charlengthdist[n]) /   Charcount(wordlist)\n",
#     "\n",
#     "#test\n",
#     "print prob(22,testWords),prob(23,testWords)\n",
#     "# 5.3.1 test if all is well : the following should add to 1 (as our longest word = 22)\n",
#     "%time print SpaceProb + sum(prob(i,testWords) for i in range(1,23) )\n",
#     "\n",
#     "# print\n",
#     "for i in range(1,23):\n",
#     "    print i,   round( prob(i,testWords),3)\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [],
#    "source": [
#     "# Faster:\n",
#     "\n",
#     "charlengthdist=nltk.FreqDist([len(w) for w in testWords])\n",
#     "def prob(n,wordlist):  \n",
#     "    return (n*charlengthdist[n]) /   Charcount(testWords)\n",
#     "\n",
#     "#test\n",
#     "print prob(22,testWords),prob(23,testWords)\n",
#     "# 5.3.1 test if all is well : the following should add to 1 (as our longest word = 22)\n",
#     "% time print SpaceProb + sum(prob(i,testWords) for i in range(1,23) )\n",
#     "\n",
#     "# print\n",
#     "for i in range(1,23):\n",
#     "    print i,   round( prob(i,testWords),3)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [],
#    "source": [
#     "# 5.4 probability of a hitting stopword\n",
#     "StopWordslen= sum(len(w) for w in StopWords)  \n",
#     "    # recall that StopWords = [ w for w in testWords if  w in stopwords.words('english')]\n",
#     "StopWordProb = StopWordslen / Charcount(testWords)\n",
#     "print StopWordProb\n",
#     "# prob of hitting a hapax\n",
#     "Hapaxlen= sum (len(w) for w in hapaxes)\n",
#     "HapaxProb = Hapaxlen / Charcount(testWords)\n",
#     "print HapaxProb"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "BONUS (if you have time left or got bored)\n",
#     "\n",
#     "Show that the  words in testWords have a Zipfian distribution. Count the words, order them by their frequency. Plot the log(frequency) times log(index of the word). \n",
#     "\n",
#     "Use `% matplotlib inline` to display the figure in the notebook.\n",
#     "\n",
#     "Is it a straight line?\n",
#     "\n",
#     "Now do the same for the unigrams and the bigrams together in one list. Is the plot \"better\"? What does 'better' mean here?\n"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 16,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [
#     {
#      "data": {
#       "image/png": [
#        "iVBORw0KGgoAAAANSUhEUgAAAXEAAAEACAYAAABF+UbAAAAABHNCSVQICAgIfAhkiAAAAAlwSFlz\n",
#        "AAALEgAACxIB0t1+/AAAIABJREFUeJzsvXmYXVWd7v+pKTVmDiEDAYQwpcRuQEFsKWhbkxBREZtB\n",
#        "H0GGxLbBxqG7ua0JTVDRVn+ioES7I/EG7HbAa6MoQ/B2h+pfGxQQGwiIEIYEMqeopIbUfO4f7/qy\n",
#        "1tm1T9WpMVV11vs85znn7L322mvvqvOu737Xd4CIiIiIiIiIiIiIiIiIiIiIiIiIiIiIiIiIiI
#        "yVAo6KbR2gJPSzmOVm04RrUDb2RTK7/j2CF3DA8iVff0vWZdHguW463L4gpX7UGuyeFtsrjO7Tcg\n",
#        "BaRuQB6N+Ns/6O1/Cpdpp/vYRNBwIdh+NhhzJ5KpeTr4jkmkgbJ2lS8gs+6odHZttEAwPo2rSKho\n",
#        "duiY97lAspjDHV+SmIz4fDAjj+bWLsvNChpCpkvvDD4/ATxP1Uz8rRV4ZQWmGYZhrEleAXY2HdUG\n",
#        "9MHmONEPNg3DMIxVzH7kPuYfwKGYbTEMwzAMwzAMA5KdCDQG/AL4M/Jc4K5YrekMGSRcdrTZwB5k\n",
#        "AJHl/A2nqkoS9wK/Bv6A1Pntdb4DvA780Vs2CPwE+DfwY3q7M0TU8X0V8Z8vIf/DGBrMNE8E6mW2\n",
#        "Ino5kOP6J64YdlL4DPB94EjchnSAx4EvIuLwPlzOQxIYBl5FLlRp4KeI1rOXeS8ioPCd3OcQBcxk\n",
#        "cAAAAfBJREFUMUU/8E3gszHY1S6iju9DyP8vjUhwPt5to4YQJ658A7i920Z0kaPA++M2oo3sAH6O\n",
#        "HFMSZ+KniGlm0wXWAf8CRhFHfhx4d4z2tItxqp3cj3ATqZuBH3bboDYzTvXx+XwE+F6jjTtRAKte\n",
#        "IlAS2YkIqn8XtyFt5OvAA7iGkkliBzID/zbwW+DzVDfd7HWuAfchjvw88CuSdW4qvo95mWRcqOpx\n",
#        "L00mU1bFcPkMIi3YP01tY8he5Q4kM+ckq6SzSJvJI5lEzyJlE/YAH43ToDZzHXKBugmZ3d1KMu+C\n",
#        "k3huRvEQME0MdxrhcMoTJO9EyiKph5+K25A282UkR/5V4DXk4tTwVq4H8dP7DgLPxGVIB7gd+IH3\n",
#        "+T7gKzHZ0k7GqQ43PItLNNyLhFd6mXFqwyl3I3dSsd0pJjkRKIU4tq/FbUiH2U8yY+JHkGJtaeSh\n",
#        "WNcfGnWQDUjexjDy0O8I8MFYLWoP40Q/2FwHfIvefrAJtcd3G6J+G4nFmoAkJwK9B4kXn0IuVieR\n",
#        "Hz1p7CeZ6pTdwIvI/+9x5AFgkrgb+CXwe0SF0+sh02eAc0g5yrPAx0iWxFCPr4gc3z2INPsMzr88\n",
#        "GZt1hmEYhmEYhmEYhmEYhmEYhmEYhmEYhmEYhmEYhmEYhmEYhmEYhmEsnf8BExlNWCx2FVoAAAAA\n",
#        "SUVORK5CYII=\n"
#       ],
#       "text/plain": [
#        "<matplotlib.figure.Figure at 0x103665f10>"
#       ]
#      },
#      "metadata": {},
#      "output_type": "display_data"
#     }
#    ],
#    "source": [
#     "% matplotlib inline\n",
#     "import math \n",
#     "\n",
#     "loglog=[ (math.log(1+i),math.log(testfd.items()[i][1])) for i in range(len(testfd.items()))] \n",
#     "# I took the code from http://rosettacode.org/wiki/Plot_coordinate_pairs#Python\n",
#     "import pylab\n",
#     "X = [i[0] for i in loglog]\n",
#     "Y = [i[1] for i in loglog]\n",
#     "pylab.plot(X, Y, 'bo')\n",
#     "pylab.show()"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {
#     "collapsed": false
#    },
#    "outputs": [],
#    "source": []
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 2",
#    "language": "python",
#    "name": "python2"
#   },
#   "language_info": {
#    "codemirror_mode": {
#     "name": "ipython",
#     "version": 2
#    },
#    "file_extension": ".py",
#    "mimetype": "text/x-python",
#    "name": "python",
#    "nbconvert_exporter": "python",
#    "pygments_lexer": "ipython2",
#    "version": "2.7.3"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 0
# }
